# %% [markdown]
# # Чтение категорий

# %%
import pandas as pd
import numpy as np

leafs = pd.read_csv('leaf_diseases/plant-pathology-2020-fgvc7/train.csv') 
leafs
# Out:
#         image_id  healthy  multiple_diseases  rust  scab
# 0        Train_0        0                  0     0     1
# 1        Train_1        0                  1     0     0
# 2        Train_2        1                  0     0     0
# 3        Train_3        0                  0     1     0
# 4        Train_4        1                  0     0     0
# ...          ...      ...                ...   ...   ...
# 1816  Train_1816        0                  0     0     1
# 1817  Train_1817        1                  0     0     0
# 1818  Train_1818        1                  0     0     0
# 1819  Train_1819        0                  0     1     0
# 1820  Train_1820        0                  0     0     1
#
# [1821 rows x 5 columns]

# %% [markdown]
# # Чтение изображений

# %%
import cv2
import os
import glob

img_dir = "leaf_diseases/plant-pathology-2020-fgvc7/images"
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
images = []
for f1 in files:
    img = cv2.imread(f1)
    images.append(img)

# %%
import matplotlib.pyplot as plt

fix,axes = plt.subplots(2,5, figsize=(15,4), subplot_kw={'xticks':(),'yticks':()})
for target, image, ax in zip(y[:10], images[:10], axes.ravel()):
    ax.imshow(image)
    ax.set_title(target)
